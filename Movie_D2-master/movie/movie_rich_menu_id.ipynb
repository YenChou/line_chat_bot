# %%
'''
菜單設定檔

    設定圖面大小、按鍵名與功能
    
'''
menuRawData1="""
{
  "size": {
    "width": 2500,
    "height": 1686
  },
  "selected": true,
  "name": "001_用戶入系統選擇",
  "chatBarText": "查看更多資訊",
  "areas": [
    {
      "bounds": {
        "x": 4,
        "y": 8,
        "width": 1271,
        "height": 1665
      },
      "action": {
        "type": "postback",
        "text": "::text:: 我要精準預測",
        "data": "我要精準預測"
      }
    },
    {
      "bounds": {
        "x": 1275,
        "y": 4,
        "width": 1225,
        "height": 1661
      },
      "action": {
        "type": "postback",
        "text": "我想看電影",
        "data": "::text:: 我想看電影"
      }
    }
  ]
}
"""
menuRawData2="""
{
  "size": {
    "width": 2500,
    "height": 1686
  },
  "selected": true,
  "name": "002_用戶預測選擇",
  "chatBarText": "查看更多資訊",
  "areas": [
    {
      "bounds": {
        "x": 0,
        "y": 4,
        "width": 1267,
        "height": 835
      },
      "action": {
        "type": "postback",
        "text": "我想看電影",
        "data": "::text:: 我想看電影"
      }
    },
    {
      "bounds": {
        "x": 1305,
        "y": 0,
        "width": 1195,
        "height": 835
      },
      "action": {
        "type": "message",
        "text": "::text:: 我填錯了想重來~"
      }
    },
    {
      "bounds": {
        "x": 8,
        "y": 869,
        "width": 1263,
        "height": 817
      },
      "action": {
        "type": "message",
        "text": "::text:: 專人馬上為你服務"
      }
    },
    {
      "bounds": {
        "x": 1297,
        "y": 869,
        "width": 1203,
        "height": 817
      },
      "action": {
        "type": "message",
        "text": "::text:: 專人馬上為你服務"
      }
    }
  ]
}
"""
menuRawData3="""
{
  "size": {
    "width": 2500,
    "height": 1686
  },
  "selected": true,
  "name": "院線&非院線",
  "chatBarText": "查看更多資訊",
  "areas": [
    {
      "bounds": {
        "x": 0,
        "y": 0,
        "width": 1025,
        "height": 1280
      },
      "action": {
        "type": "postback",
        "text": "我要院線片",
        "data": "::text:: 我要院線片"
      }
    },
    {
      "bounds": {
        "x": 1483,
        "y": 0,
        "width": 1017,
        "height": 1291
      },
      "action": {
        "type": "postback",
        "text": "我要非院線片",
        "data": "::text:: 我要非院線片"
      }
    },
    {
      "bounds": {
        "x": 1026,
        "y": 1148,
        "width": 457,
        "height": 538
      },
      "action": {
        "type": "postback",
        "text": "回首頁",
        "data": "::回首頁"
      }
    }
  ]
}
"""

menuRawData4="""
{
  "size": {
    "width": 2500,
    "height": 1686
  },
  "selected": true,
  "name": "填選表單確認頁",
  "chatBarText": "查看更多資訊",
  "areas": [
    {
      "bounds": {
        "x": 0,
        "y": 0,
        "width": 1254,
        "height": 1686
      },
      "action": {
        "type": "postback",
        "text": "確認填選表單",
        "data": "::確認填選表單"
      }
    },
    {
      "bounds": {
        "x": 1250,
        "y": 0,
        "width": 1250,
        "height": 1686
      },
      "action": {
        "type": "postback",
        "text": "回首頁",
        "data": "::回首頁"
      }
    }
  ]
}
"""

# %%
'''

讀取安全檔案內的字串，以供後續程式碼調用

'''
import json
secretFileContentJson=json.load(open("../line_secret_key",'r'))

print(secretFileContentJson.get("channel_access_token"))
print(secretFileContentJson.get("secret_key"))
print(secretFileContentJson.get("self_user_id"))
# Out:
# haCtdg071V/Y/tB8BOTdlrysQpbYyuog+Vj83VZsxjKBqAA4CbRRQLkBclg/J4kDbpyPLo+Jw0BtC5JdacQ6WqnnJmPnBrgnnBBo8qA0h7LlESxYXvFds+iElTYgdSMiZT3nlZUuJPuXzk9GwSjfglGUYhWQfeY8sLGRXgo3xvw=
# 9236592239015f93816274d097fcfdd6
# U6f2dfaaac958fb9dcc653bfe6cfcc40b

# %%
'''
取的第一個菜單的設定檔
將先前準備的菜單設定檔，以Post消息寄發給Line

    設定Line的遠端位置
    設定消息的基本安全憑證
    寄發消息，並取得回應之Id
    

'''

import requests

menuJson=json.loads(menuRawData1)

createMenuEndpoint = 'https://api.line.me/v2/bot/richmenu'
createMenuRequestHeader={'Content-Type':'application/json','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

#print(createMenuRequestHeader)

lineCreateMenuResponse = requests.post(createMenuEndpoint,headers=createMenuRequestHeader,data=json.dumps(menuJson))

print(lineCreateMenuResponse)
print(lineCreateMenuResponse.text)
# Out:
# <Response [200]>
# {"richMenuId":"richmenu-ed707e5f25f1ee44f87906c533386d61"}

# %%
'''
FIRST
將先前準備的菜單照片，以Post消息寄發給Line
    取得上面設定檔的Id
    設定Line的遠端位置
    設定消息的基本安全憑證
    上傳照片，並取得回傳成果

'''

# 取得菜單Id 
uploadRichMenuId=json.loads(lineCreateMenuResponse.text).get("richMenuId")
print(uploadRichMenuId)
#'https://api.line.me/v2/bot/richmenu/{richMenuId}/content'

# 設定Line的遠端位置
uploadMenuEndpoint='https://api.line.me/v2/bot/richmenu/%s/content' % uploadRichMenuId
print(uploadMenuEndpoint)

# 設定消息的基本安全憑證
uploadMenuRequestHeader={'Content-Type':'image/jpeg','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 上傳照片
uploadImageFile=open("../images/pic1_resized.jpg",'rb')
lineUploadMenuResponse=requests.post(uploadMenuEndpoint,headers=uploadMenuRequestHeader,data=uploadImageFile)

print(lineUploadMenuResponse)
print(lineUploadMenuResponse.text)
# Out:
# richmenu-ed707e5f25f1ee44f87906c533386d61
# https://api.line.me/v2/bot/richmenu/richmenu-ed707e5f25f1ee44f87906c533386d61/content
# <Response [200]>
# {}

# %%
'''
取得第二個菜單的設定檔
將先前準備的菜單設定檔，以Post消息寄發給Line

    設定Line的遠端位置
    設定消息的基本安全憑證
    寄發消息，並取得回應之Id
    

'''

import requests

menuJson2=json.loads(menuRawData2)

createMenuEndpoint = 'https://api.line.me/v2/bot/richmenu'
createMenuRequestHeader2={'Content-Type':'application/json','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

#print(createMenuRequestHeader)

lineCreateMenuResponse2 = requests.post(createMenuEndpoint,headers=createMenuRequestHeader2,data=json.dumps(menuJson2))

print(lineCreateMenuResponse2)
print(lineCreateMenuResponse2.text)
# Out:
# <Response [200]>
# {"richMenuId":"richmenu-e6161f87bfbd2d9c06e28eb7fb86d4af"}

# %%
'''
SECOND
將先前準備的菜單照片，以Post消息寄發給Line
    取得上面設定檔的Id
    設定Line的遠端位置
    設定消息的基本安全憑證
    上傳照片，並取得回傳成果

'''

# 取得菜單Id 
uploadRichMenuId2=json.loads(lineCreateMenuResponse2.text).get("richMenuId")
print(uploadRichMenuId2)
#'https://api.line.me/v2/bot/richmenu/{richMenuId}/content'

# 設定Line的遠端位置
uploadMenuEndpoint2='https://api.line.me/v2/bot/richmenu/%s/content' % uploadRichMenuId2
print(uploadMenuEndpoint2)

# 設定消息的基本安全憑證
uploadMenuRequestHeader={'Content-Type':'image/jpeg','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 上傳照片
uploadImageFile2=open("../images/pic2_resized.jpg",'rb')
lineUploadMenuResponse2=requests.post(uploadMenuEndpoint2,headers=uploadMenuRequestHeader,data=uploadImageFile2)

print(lineUploadMenuResponse2)
print(lineUploadMenuResponse2.text)
# Out:
# richmenu-e6161f87bfbd2d9c06e28eb7fb86d4af
# https://api.line.me/v2/bot/richmenu/richmenu-e6161f87bfbd2d9c06e28eb7fb86d4af/content
# <Response [200]>
# {}

# %%
'''
取得第三個菜單的設定檔
將先前準備的菜單設定檔，以Post消息寄發給Line

    設定Line的遠端位置
    設定消息的基本安全憑證
    寄發消息，並取得回應之Id
    

'''

import requests

menuJson3=json.loads(menuRawData3)

createMenuEndpoint = 'https://api.line.me/v2/bot/richmenu'
createMenuRequestHeader3={'Content-Type':'application/json','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

#print(createMenuRequestHeader)

lineCreateMenuResponse3 = requests.post(createMenuEndpoint,headers=createMenuRequestHeader3,data=json.dumps(menuJson3))

print(lineCreateMenuResponse3)
print(lineCreateMenuResponse3.text)
# Out:
# <Response [200]>
# {"richMenuId":"richmenu-b1c80f857477e65e13df40c32d231599"}

# %%
'''
THIRD
將先前準備的菜單照片，以Post消息寄發給Line
    取得上面設定檔的Id
    設定Line的遠端位置
    設定消息的基本安全憑證
    上傳照片，並取得回傳成果

'''

# 取得菜單Id 
uploadRichMenuId3=json.loads(lineCreateMenuResponse3.text).get("richMenuId")
print(uploadRichMenuId3)
#'https://api.line.me/v2/bot/richmenu/{richMenuId}/content'

# 設定Line的遠端位置
uploadMenuEndpoint3='https://api.line.me/v2/bot/richmenu/%s/content' % uploadRichMenuId3
print(uploadMenuEndpoint3)

# 設定消息的基本安全憑證
uploadMenuRequestHeader={'Content-Type':'image/jpeg','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 上傳照片
uploadImageFile3=open("../images/院線非院線1.jpg",'rb')
lineUploadMenuResponse3=requests.post(uploadMenuEndpoint3,headers=uploadMenuRequestHeader,data=uploadImageFile3)

print(lineUploadMenuResponse3)
print(lineUploadMenuResponse3.text)
# Out:
# richmenu-b1c80f857477e65e13df40c32d231599
# https://api.line.me/v2/bot/richmenu/richmenu-b1c80f857477e65e13df40c32d231599/content
# <Response [200]>
# {}

# %%
'''
取得第四個菜單的設定檔
將先前準備的菜單設定檔，以Post消息寄發給Line

    設定Line的遠端位置
    設定消息的基本安全憑證
    寄發消息，並取得回應之Id
    

'''

import requests

menuJson4=json.loads(menuRawData4)

createMenuEndpoint = 'https://api.line.me/v2/bot/richmenu'
createMenuRequestHeader4={'Content-Type':'application/json','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

#print(createMenuRequestHeader)

lineCreateMenuResponse4 = requests.post(createMenuEndpoint,headers=createMenuRequestHeader4,data=json.dumps(menuJson4))

print(lineCreateMenuResponse4)
print(lineCreateMenuResponse4.text)
# Out:
# <Response [200]>
# {"richMenuId":"richmenu-4a1a01b0d191b1fd2fd8be489b5ec557"}

# %%
'''
FOURTH
將先前準備的菜單照片，以Post消息寄發給Line
    取得上面設定檔的Id
    設定Line的遠端位置
    設定消息的基本安全憑證
    上傳照片，並取得回傳成果

'''

# 取得菜單Id 
uploadRichMenuId4=json.loads(lineCreateMenuResponse4.text).get("richMenuId")
print(uploadRichMenuId4)
#'https://api.line.me/v2/bot/richmenu/{richMenuId}/content'

# 設定Line的遠端位置
uploadMenuEndpoint4='https://api.line.me/v2/bot/richmenu/%s/content' % uploadRichMenuId4
print(uploadMenuEndpoint4)

# 設定消息的基本安全憑證
uploadMenuRequestHeader={'Content-Type':'image/jpeg','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 上傳照片
uploadImageFile4=open("../images/填選表單確認頁.jpg",'rb')
lineUploadMenuResponse4=requests.post(uploadMenuEndpoint4,headers=uploadMenuRequestHeader,data=uploadImageFile4)

print(lineUploadMenuResponse4)
print(lineUploadMenuResponse4.text)
# Out:
# richmenu-4a1a01b0d191b1fd2fd8be489b5ec557
# https://api.line.me/v2/bot/richmenu/richmenu-4a1a01b0d191b1fd2fd8be489b5ec557/content
# <Response [200]>
# {}

# %%
'''

將選單綁定到特定用戶身上
    取出上面得到的菜單Id及用戶id
    設定Line的遠端位置
    設定消息的基本安全憑證
    發送消息告知

'''

# https://api.line.me/v2/bot/user/{userId}/richmenu/{richMenuId}

# 取得菜單id
linkRichMenuId=json.loads(lineCreateMenuResponse.text).get("richMenuId")

# 將菜單id與用戶id組合成遠端位置
linkMenuEndpoint='https://api.line.me/v2/bot/user/%s/richmenu/%s' % (secretFileContentJson["self_user_id"], linkRichMenuId)
print(linkMenuEndpoint)

# 設定消息基本安全憑證
linkMenuRequestHeader={'Content-Type':'image/jpeg','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 發送消息
lineLinkMenuResponse=requests.post(linkMenuEndpoint,headers=linkMenuRequestHeader)
print(lineLinkMenuResponse)
print(lineLinkMenuResponse.text)
